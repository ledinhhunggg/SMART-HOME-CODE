# %%
from pop import Cds
import time

cds = Cds(7)

while True:
    val = cds.readAverage()
    print(val)

    time.sleep(0.1)
# Out:
# 1740
# 1740
# 1742
# 1742
# 1745
# 1746
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1a69b632900b> in <module>
#       8     print(val)
#       9
# ---> 10     time.sleep(0.1)
#
# KeyboardInterrupt:

# %%
from pop import Cds
import time

cds = Cds(7)

def onCds(val, unuse):
    print(val)

    time.sleep(0.2)

cds.setCallback(onCds)
input("Press <Enter> key...\n")
# Out:
# 1785
# 1792
# 1784
# 1805
# 1807
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-687e92aa007a> in <module>
#      10
#      11 cds.setCallback(onCds)
# ---> 12 input("Press <Enter> key...\n")
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     891             except KeyboardInterrupt:
#     892                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 893                 raise KeyboardInterrupt("Interrupted by user") from None
#     894             else:
#     895                 break
#
# ...
